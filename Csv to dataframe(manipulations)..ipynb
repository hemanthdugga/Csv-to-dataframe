# %%
import pandas as pd

# %%
pf=pd.read_csv(r"C:\Users\D Hemanth Kumar Redd\Downloads\StudentsPerformance.csv")

# %%
pf1=pf.copy()

# %%
pf
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # 1.New column for percentage:

# %%
total=pf1["math score"]+pf1["reading score"]+pf1["writing score"]

# %%
pf1["percentage"]=total/300*100
pf1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    percentage
# 0   72.666667
# 1   82.333333
# 2   92.666667
# 3   49.333333
# 4   76.333333

# %% [markdown]
# # 2) All males having greater than 50% marks

# %%
pf1.loc[(pf1["percentage"]>50) & (pf1["gender"]== "male")]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 4     male        group C                some college      standard
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 4                      none          76             78             75
# ...

# %%
pf1.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      percentage
# 995   94.000000
# 996   57.333333
# 997   65.000000
# 998   74.333333
# 999   83.000000

# %% [markdown]
# # 3) All mens having less than 50% marks

# %%
pf1.loc[(pf1["gender"]=="male") & (pf1["percentage"]<50)]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 7     male        group B                some college  free/reduced
# 11    male        group D          associate's degree      standard
# 18    male        group C             master's degree  free/reduced
# 33    male        group D                some college      standard
# ..     ...            ...                         ...           ...
# 889   male        group D                 high school  free/reduced
# 896   male        group B                 high school  free/reduced
# 910   male        group D           bachelor's degree  free/reduced
# 928   male        group E          associate's degree  free/reduced
# 978   male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none          47             57             44
# ...

# %% [markdown]
# # 4) All females having less than 50% mark

# %%
pf1.loc[(pf1["gender"]=="female") & (pf1["percentage"]<50)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 55   female        group C                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 72   female        group A          associate's degree  free/reduced
# 80   female        group B          associate's degree      standard
# 145  female        group C                some college  free/reduced
# 174  female        group C           bachelor's degree  free/reduced
# 182  female        group E                 high school      standard
# 217  female        group C                 high school  free/reduced
# 262  female        group C            some high school  free/reduced
# 284  female        group B            some high school      standard
# 323  female        group C            some high school  free/reduced
# ...

# %% [markdown]
# # 5) All females having greater than 50%

# %%
pf1.loc[(pf1["gender"]=="female") & (pf1["percentage"]>50)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # 6) count how many female candidates are there

# %%
fm=pf1.loc[pf1["gender"]=="female"]
print(fm)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
fm=print("Total number of female students are : ",len(fm.index))
# Out:
# Total number of female students are :  518

# %% [markdown]
# # 7) count howmany male candidates are there

# %%
ml=pf1.loc[pf1["gender"]=="male"]

# %%
ml
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none          47             57             44
# ...

# %%
print("Total number of male students are : ",len(ml.index))
# Out:
# Total number of male students are :  482

# %% [markdown]
# # 8) howmany student's parent's education is bachelor's degree

# %%
degree=pf1.loc[pf1["parental level of education"]=="bachelor's degree"]

# %%
print("Total parents having bachelor' degree : ",len(degree))
# Out:
# Total parents having bachelor' degree :  118

# %% [markdown]
# # 9) howmany Males and females having standard lunch:

# %%
print("total students having standard lunch = ",len(pf1.loc[pf1["lunch"]=="standard"]))
# Out:
# total students having standard lunch =  645

# %% [markdown]
# # 10)howmany Males and females having free/reduced lunch

# %%
print("total students having free/reduced lunch = ",len(pf1.loc[pf1["lunch"]=="free/reduced"]))
# Out:
# total students having free/reduced lunch =  355
